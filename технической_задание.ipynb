# %% [markdown]
# <a href="https://colab.research.google.com/github/merrymilk/GB/blob/main/%D1%82%D0%B5%D1%85%D0%BD%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B9_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown

# !gdown 'https://drive.google.com/uc?id=1pmfc0FrkMvlM2SITpFz6bilk-dvDG_y0'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pmfc0FrkMvlM2SITpFz6bilk-dvDG_y0
# To: /content/data.db
# 100% 16.0M/16.0M [00:00<00:00, 166MB/s]

# %%
# !pip install SQLAlchemy==2.0.21
# %load_ext sql
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:////content/data.db

# %config SqlMagic.displaylimit = 50

# %%
# %sql select tbl_name, "sql" from sqlite_master;
# Out:
#  * sqlite:////content/data.db
# Done.
# [('mngmnt', 'CREATE TABLE mngmnt (\n\torg_management_rk BIGINT, \n\tmanagement_nm TEXT\n)'),
#  ('product', 'CREATE TABLE product (\n\thit_rk BIGINT, \n\thid BIGINT, \n\tusing_flg FLOAT\n)'),
#  ('queue', 'CREATE TABLE queue (\n\tqueue_id BIGINT, \n\tqueue_desc TEXT\n)'),
#  ('result', 'CREATE TABLE result (\n\thit_status_result_id BIGINT, \n\thit_status_result_desc TEXT\n)'),
#  ('horoscope', 'CREATE TABLE horoscope (\n\tagent_login TEXT, \n\thoroscope TEXT\n)'),
#  ('group', 'CREATE TABLE "group" (\n\torg_group_rk BIGINT, \n\torg_management_rk BIGINT, \n\tgroup_nm TEXT\n)'),
#  ('emp_x_org_gr', 'CREATE TABLE emp_x_org_gr (\n\temployee_rk BIGINT, \n\torg_group_rk BIGINT\n)'),
#  ('task', 'CREATE TABLE task (\n\ttask_rk BIGINT, \n\ttask_stage_id FLOAT, \n\tsource_system_cd TEXT, \n\tcreate_dttm TEXT, \n\tfinish_dttm TEXT\n)'),
#  ('action', 'CREATE TABLE action (\n\thit_rk BIGINT, \n\thit_status_result_id BIGINT\n)'),
# ...

# %%
# %%sql
# select * from "group"
# union
# select * from product;
# Out:
#  * sqlite:////content/data.db
# Done.
# [(58, 325, 'Группа 42'),
#  (252, 401, 'Группа 13'),
#  (255, 445, 'Группа 45'),
#  (262, 375, 'Группа 7'),
#  (378, 415, 'Группа 41'),
#  (390, 388, 'Группа 46'),
#  (427, 370, 'Группа 14'),
#  (627, 378, 'Группа 38'),
#  (719, 443, 'Группа 28'),
#  (771, 439, 'Группа 43'),
#  (900, 483, 'Группа 49'),
#  (954, 4, None),
#  (960, 402, 'Группа 15'),
#  (2031, 674, 'Группа 23'),
#  (2077, 307, 'Группа 47'),
#  (2097, 687, 'Группа 19'),
#  (2105, 689, 'Группа 31'),
#  (2108, 691, 'Группа 21'),
#  (2136, 696, 'Группа 48'),
#  (2138, 1521, 'Группа 29'),
#  (2264, 1, None),
#  (2351, 1636, 'Группа 1'),
#  (2389, 323, 'Группа 5'),
#  (2430, 1699, 'Группа 26'),
#  (2447, 1711, 'Группа 9'),
#  (2469, 1594, 'Группа 40'),
#  (2486, 674, 'Группа 37'),
#  (2517, 1718, 'Группа 25'),
#  (2518, 1719, 'Группа 35'),
#  (2531, 1720, 'Группа 3'),
#  (2550, 349, 'Группа 32'),
#  (2553, 388, 'Группа 6'),
#  (2558, 1726, 'Группа 12'),
#  (2568, 1728, 'Группа 20'),
# ...

# %%
# %%sql
# SELECT * FROM result;
# Out:
#  * sqlite:////content/data.db
# Done.
# [(8, 'Дозвон, Некорректное задание по звонку'),
#  (1, 'Дозвон, Отказ'),
#  (6, 'Дозвон, Отложить'),
#  (4, 'Не было звонка'),
#  (2, 'Дозвон, Перезвонить'),
#  (5, 'Недозвон'),
#  (3, 'Дозвон, Успешно')]

# %%
# %%sql
# SELECT * FROM result where hit_status_result_id between 3 and 3;
# Out:
#  * sqlite:////content/data.db
# Done.
# [(3, 'Дозвон, Успешно')]

# %%
# %%sql
# select 3+1 as "Конверсия";
# Out:
#  * sqlite:////content/data.db
# Done.
# [(4,)]

# %%
# %%sql
# select 3 / 4 as "Продажная конверсия";
# Out:
#  * sqlite:////content/data.db
# Done.
# [(0,)]

# %%
# %%sql
# select avg(duratoin_sec) from call where duratoin_sec > 0;
# Out:
#  * sqlite:////content/data.db
# Done.
# [(112.25156400072684,)]
